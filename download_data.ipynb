# %% [markdown]
# # Download Data from Google Drive
# This notebook downloads the required data zip file from Google Drive and unzips it.

# %%
# !pip install gdown

# %%
import gdown
import zipfile
import os

file_id = '139BfNfWUiuted5EH4tXGeI-Of10ikWvP'
output = 'data.zip'

# Download the file using the file ID
gdown.download(id=file_id, output=output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=139BfNfWUiuted5EH4tXGeI-Of10ikWvP
# From (redirected): https://drive.google.com/uc?id=139BfNfWUiuted5EH4tXGeI-Of10ikWvP&confirm=t&uuid=43987d29-b232-40d1-a392-4f30cafdc01d
# To: /Users/gianlucacaregnato/Desktop/VisionExplainability/data.zip
#   0%|          | 2.10M/12.5G [00:04<7:58:47, 435kB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       5 file_id = '139BfNfWUiuted5EH4tXGeI-Of10ikWvP'
#       6 output = 'data.zip'
#       7
#       8 # Download the file using the file ID
# ----> 9 gdown.download(id=file_id, output=output, quiet=False)
#      10
#
# File ~/Desktop/VisionExplainability/.venv/lib/python3.14/site-packages/gdown/download.py:398, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, resume, format, user_agent, log_messages, progress)
# ...

# %%
# Unzip the file
print("Extracting files...")
with zipfile.ZipFile(output, 'r') as zip_ref:
    zip_ref.extractall('drive_folder')
    
print("Extraction complete!")
