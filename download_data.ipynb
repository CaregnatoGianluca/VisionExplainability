# %% [markdown]
# # Download Data from Google Drive
# This notebook downloads the required data zip file from Google Drive and unzips it.

# %%
# !pip install gdown
import gdown
import zipfile
import glob
import os
# Out:
# Requirement already satisfied: gdown in ./.venv/lib/python3.14/site-packages (6.1.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.14/site-packages (from gdown) (4.14.3)
# Requirement already satisfied: filelock in ./.venv/lib/python3.14/site-packages (from gdown) (3.29.1)
# Requirement already satisfied: requests[socks] in ./.venv/lib/python3.14/site-packages (from gdown) (2.34.2)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.14/site-packages (from gdown) (4.68.1)
# Requirement already satisfied: soupsieve>=1.6.1 in ./.venv/lib/python3.14/site-packages (from beautifulsoup4->gdown) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./.venv/lib/python3.14/site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.14/site-packages (from requests[socks]->gdown) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.14/site-packages (from requests[socks]->gdown) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./.venv/lib/python3.14/site-packages (from requests[socks]->gdown) (2026.5.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in ./.venv/lib/python3.14/site-packages (from requests[socks]->gdown) (1.7.1)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# The ID of the main Google Drive folder you provided
folder_id = '1wuTAAaRszHnR4XrdS_97RJ3p6mYTCF1k'
output_folder = 'drive_folder/'

# %%
# Download the entire folder automatically
print("Downloading folder from Google Drive...")
gdown.download_folder(id=folder_id, output=output_folder, quiet=False)
# Out:
# Downloading folder from Google Drive...
# Retrieving folder contents
# Processing file 17QNpC5aAYSBuJ9JRhIF9Q8X_94gIAk3t CNN.zip
# Processing file 1XL_dmvnUHcVXmLMWLXNybi2vcluX568i CUB.zip
# Processing file 1uIGBg4KvIhFaerIQZwFMc_OxLit9SO5R CXR.zip
# Processing file 1xWmej_Ky7Kx5-rkEes-vqwgQnvJilR9Z KDEF.zip
# Processing file 1DbJ6uYHS2gJrXGpOfBjt42YzNY8dvxoV Mamba.zip
# Processing file 1Juk7FOFT86MRBFQCAgDlImnUyzZuSoJ2 Transformer.zip
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=17QNpC5aAYSBuJ9JRhIF9Q8X_94gIAk3t
# From (redirected): https://drive.google.com/uc?id=17QNpC5aAYSBuJ9JRhIF9Q8X_94gIAk3t&confirm=t&uuid=4f8b5f22-0e96-409b-b899-e33c762bfcbf
# To: /Users/gianlucacaregnato/VisionExplainability/drive_folder/Bridging_Human_and_Model_Attention_Explainability_Analysis_of_CNN_Mamba_and_ViT_Architectures_with_Gaze-Based_Validation/CNN.zip
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Download the entire folder automatically
#       2 print("Downloading folder from Google Drive...")
# ----> 3 gdown.download_folder(id=folder_id, output=output_folder, quiet=False)
#
# File ~/VisionExplainability/.venv/lib/python3.14/site-packages/gdown/download_folder.py:185, in download_folder(url, id, output, quiet, proxy, speed, use_cookies, verify, user_agent, skip_download, resume)
#     183         else:
#     184             download_output = osp.dirname(local_path) + osp.sep
# --> 185         local_path = download(
#     186             url="https://drive.google.com/uc?id=" + id,
#     187             output=download_output,
#     188             quiet=quiet,
#     189             proxy=proxy,
#     190             speed=speed,
#     191             use_cookies=use_cookies,
#     192             verify=verify,
#     193             resume=resume,
#     194         )
#     195         files.append(local_path)
#     196 if not quiet:
#
# File ~/VisionExplainability/.venv/lib/python3.14/site-packages/gdown/download.py:421, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, resume, format, user_agent, log_messages, progress, skip_download)
#     419 t_start = time.time()
#     420 downloaded = 0
# --> 421 for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#     422     f.write(chunk)
#     423     downloaded += len(chunk)
#
# File ~/VisionExplainability/.venv/lib/python3.14/site-packages/requests/models.py:937, in Response.iter_content.<locals>.generate()
#     935 if hasattr(self.raw, "stream"):
#     936     try:
# --> 937         yield from self.raw.stream(chunk_size, decode_content=True)
#     938     except ProtocolError as e:
#     939         raise ChunkedEncodingError(e)
#
# File ~/VisionExplainability/.venv/lib/python3.14/site-packages/urllib3/response.py:1267, in HTTPResponse.stream(self, amt, decode_content)
#    1261 else:
#    1262     while (
#    1263         not is_fp_closed(self._fp)
#    1264         or len(self._decoded_buffer) > 0
#    1265         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1266     ):
# -> 1267         data = self.read(amt=amt, decode_content=decode_content)
#    1269         if data:
#    1270             yield data
#
# File ~/VisionExplainability/.venv/lib/python3.14/site-packages/urllib3/response.py:1110, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1107     if len(self._decoded_buffer) >= amt:
#    1108         return self._decoded_buffer.get(amt)
# -> 1110 data = self._raw_read(amt)
#    1111 if not cache_content:
#    1112     self._uncached_read_occurred = True
#
# File ~/VisionExplainability/.venv/lib/python3.14/site-packages/urllib3/response.py:1022, in HTTPResponse._raw_read(self, amt, read1)
#    1019 fp_closed = getattr(self._fp, "closed", False)
#    1021 with self._error_catcher():
# -> 1022     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1023     if amt is not None and amt != 0 and not data:
#    1024         # Platform-specific: Buggy versions of Python.
#    1025         # Close the connection when no data is returned
#    (...)   1030         # not properly close the connection in all cases. There is
#    1031         # no harm in redundantly calling close.
#    1032         self._fp.close()
#
# File ~/VisionExplainability/.venv/lib/python3.14/site-packages/urllib3/response.py:1005, in HTTPResponse._fp_read(self, amt, read1)
#    1002     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#    1003 else:
#    1004     # StringIO doesn't like amt=None
# -> 1005     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:484, in HTTPResponse.read(self, amt)
#     481 if self.length is not None and amt > self.length:
#     482     # clip the read to the "end of response"
#     483     amt = self.length
# --> 484 s = self.fp.read(amt)
#     485 if not s and amt:
#     486     # Ideally, we would raise IncompleteRead if the content-length
#     487     # wasn't satisfied, but it might break compatibility.
#     488     self._close_conn()
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/socket.py:725, in SocketIO.readinto(self, b)
#     723     raise OSError("cannot read from timed out object")
#     724 try:
# --> 725     return self._sock.recv_into(b)
#     726 except timeout:
#     727     self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Unzip all downloaded zip files
print("Extracting files...")

# Find all zip files downloaded in the folder (and subfolders)
zip_files = glob.glob(os.path.join(output_folder, '**', '*.zip'), recursive=True)

for zip_file in zip_files:
    print(f"Extracting {zip_file}...")
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(output_folder)
    
print("Extraction complete!")
