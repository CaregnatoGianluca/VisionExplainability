# %% [markdown]
# # Download Data from Google Drive
# This notebook downloads the required data zip file from Google Drive and unzips it.

# %%
# !pip install gdown

# %%
import gdown
import zipfile
import os

file_id = '14XVhNQsAn3BQjliU15PKEzLTY1x66xDY'
output = 'data.zip'

# Download the file using the file ID
gdown.download(id=file_id, output=output, quiet=False)

# %%
# Unzip the file
print("Extracting files...")
with zipfile.ZipFile(output, 'r') as zip_ref:
    zip_ref.extractall('drive_folder')
    
print("Extraction complete!")
# Out:
# Extracting files...
#   0%|          | 0.00/2.06G [1:25:57<?, ?B/s]
# Extraction complete!
